# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import curve_fit

# %%
def chi_sq(x, y, err):
    function = lambda x, a, b: a * x + b
    popt, pcov = curve_fit(function, xdata=x, ydata=y, sigma=err)

    sigma_a = np.sqrt(pcov[0, 0])
    sigma_b = np.sqrt(pcov[1, 1])

    return popt[0], popt[1], sigma_a, sigma_b

# %%
sns.set_theme()
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rcParams["figure.figsize"] = (15,10)

# %%
c13 = pd.read_csv('13.csv', sep = '\t')
c14 = pd.read_csv('14.csv', sep = '\t')
c16 = pd.read_csv('16.csv', sep = '\t')
c17 = pd.read_csv('17.csv', sep = '\t')
c19 = pd.read_csv('19.csv', sep = '\t')
c20 = pd.read_csv('20.csv', sep = '\t')
c22 = pd.read_csv('22.csv', sep = '\t')
c23 = pd.read_csv('23.csv', sep = '\t')
c25 = pd.read_csv('25.csv', sep = '\t')
c26 = pd.read_csv('26.csv', sep = '\t')
c28 = pd.read_csv('28.csv', sep = '\t')
c29 = pd.read_csv('29.csv', sep = '\t')

# %%
new_columns = list(['t', 'u'])
c14.columns = new_columns
c16.columns = new_columns
c17.columns = new_columns
c19.columns = new_columns
c20.columns = new_columns
c22.columns = new_columns
c23.columns = new_columns
c25.columns = new_columns
c26.columns = new_columns
c28.columns = new_columns
c29.columns = new_columns

# %%
c14
# Out:
#             t       u
# 0      0,0002  0,1180
# 1      0,0004  0,1269
# 2      0,0006  0,1154
# 3      0,0008  0,1295
# 4      0,0010  0,1154
# ...       ...     ...
# 49989  9,9980  0,1205
# 49990  9,9982  0,1256
# 49991  9,9984  0,1295
# 49992  9,9986  0,1320
# 49993  9,9988  0,1282
#
# [49994 rows x 2 columns]

# %%
c14['t'].replace(',', '.', inplace = True, regex = True)
c14['u'].replace(',', '.',inplace = True, regex = True)
c14['t'] = pd.to_numeric(c14['t'])
c14['u'] = pd.to_numeric(c14['u'])

# %%
c16['t'].replace(',', '.', inplace = True, regex = True)
c16['u'].replace(',', '.',inplace = True, regex = True)
c16['t'] = pd.to_numeric(c16['t'])
c16['u'] = pd.to_numeric(c16['u'])

c16_u = np.array(c16['u'])

for i in range(400, len(c16['u']) - 400):
    c16_u[i] = np.average(c16['u'][i-400:i+400])

# %%
c14_u = np.array(c14['u'])

for i in range(400, len(c14['u']) - 400):
    c14_u[i] = np.average(c14['u'][i-400:i+400])

# %%
plt.plot(c14['t'], c14_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c14_u[400:49594]))
# Out:
# 0.12847911511312354

# %%
np.average(c14_u[400:49594])
# Out:
# 0.12847911511312354

# %%
c17['t'].replace(',', '.', inplace = True, regex = True)
c17['u'].replace(',', '.',inplace = True, regex = True)
c17['t'] = pd.to_numeric(c17['t'])
c17['u'] = pd.to_numeric(c17['u'])

c17_u = np.array(c17['u'])

for i in range(400, len(c17['u']) - 400):
    c17_u[i] = np.average(c17['u'][i-400:i+400])

# %%
c19['t'].replace(',', '.', inplace = True, regex = True)
c19['u'].replace(',', '.',inplace = True, regex = True)
c19['t'] = pd.to_numeric(c19['t'])
c19['u'] = pd.to_numeric(c19['u'])

c19_u = np.array(c19['u'])

for i in range(400, len(c19['u']) - 400):
    c19_u[i] = np.average(c19['u'][i-400:i+400])

# %%
c20['t'].replace(',', '.', inplace = True, regex = True)
c20['u'].replace(',', '.',inplace = True, regex = True)
c20['t'] = pd.to_numeric(c20['t'])
c20['u'] = pd.to_numeric(c20['u'])

c20_u = np.array(c20['u'])

for i in range(400, len(c20['u']) - 400):
    c20_u[i] = np.average(c20['u'][i-400:i+400])

# %%
c22['t'].replace(',', '.', inplace = True, regex = True)
c22['u'].replace(',', '.',inplace = True, regex = True)
c22['t'] = pd.to_numeric(c22['t'])
c22['u'] = pd.to_numeric(c22['u'])

c22_u = np.array(c22['u'])

for i in range(400, len(c22['u']) - 400):
    c22_u[i] = np.average(c22['u'][i-400:i+400])

# %%
c23['t'].replace(',', '.', inplace = True, regex = True)
c23['u'].replace(',', '.',inplace = True, regex = True)
c23['t'] = pd.to_numeric(c23['t'])
c23['u'] = pd.to_numeric(c23['u'])

c23_u = np.array(c23['u'])

for i in range(400, len(c23['u']) - 400):
    c23_u[i] = np.average(c23['u'][i-400:i+400])

# %%
c25['t'].replace(',', '.', inplace = True, regex = True)
c25['u'].replace(',', '.',inplace = True, regex = True)
c25['t'] = pd.to_numeric(c25['t'])
c25['u'] = pd.to_numeric(c25['u'])

c25_u = np.array(c25['u'])

for i in range(400, len(c25['u']) - 400):
    c25_u[i] = np.average(c25['u'][i-400:i+400])

# %%
c26['t'].replace(',', '.', inplace = True, regex = True)
c26['u'].replace(',', '.',inplace = True, regex = True)
c26['t'] = pd.to_numeric(c26['t'])
c26['u'] = pd.to_numeric(c26['u'])

c26_u = np.array(c26['u'])

for i in range(400, len(c26['u']) - 400):
    c26_u[i] = np.average(c26['u'][i-400:i+400])

# %%
c28['t'].replace(',', '.', inplace = True, regex = True)
c28['u'].replace(',', '.',inplace = True, regex = True)
c28['t'] = pd.to_numeric(c28['t'])
c28['u'] = pd.to_numeric(c28['u'])

c28_u = np.array(c28['u'])

for i in range(400, len(c28['u']) - 400):
    c28_u[i] = np.average(c28['u'][i-400:i+400])

# %%
c29['t'].replace(',', '.', inplace = True, regex = True)
c29['u'].replace(',', '.',inplace = True, regex = True)
c29['t'] = pd.to_numeric(c29['t'])
c29['u'] = pd.to_numeric(c29['u'])

c29_u = np.array(c29['u'])

for i in range(400, len(c29['u']) - 400):
    c29_u[i] = np.average(c29['u'][i-400:i+400])

# %%
plt.plot(c16['t'], c16_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c16_u[400:49594]))
# Out:
# 0.29854020440754975

# %%
plt.plot(c17['t'], c17['u'])

# %%
plt.hist(c17['u'], bins = 1000)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
# ...

# %%
plt.plot(c17['t'], c17_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c17_u[400:49594]))
# Out:
# 0.37746042733107693

# %%
plt.plot(c19['t'], c19_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c19_u[400:49594]))
# Out:
# 0.4932194969838801

# %%
plt.plot(c20['t'], c20_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c20_u[400:49594]))
# Out:
# 0.5526446992290727

# %%
plt.plot(c22['t'], c22_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c22_u[400:49594]))
# Out:
# 0.6424869667134203

# %%
plt.plot(c23['t'], c23_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c23_u[400:49594]))
# Out:
# 0.6868852084603813

# %%
plt.plot(c25['t'], c25_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c25_u[400:49594]))
# Out:
# 0.7665522596785177

# %%
plt.plot(c26['t'], c26_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c26_u[400:49594]))
# Out:
# 0.8155792358341464

# %%
plt.plot(c28['t'], c28_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c28_u[400:49594]))
# Out:
# 0.9000778546291214

# %%
plt.plot(c29['t'], c29_u)
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c29_u[400:49594]))
# Out:
# 0.9601224107131966

# %%
c29_2 = pd.read_csv('29_2.csv', sep = '\t')
c29_2.columns = new_columns

c29_2['t'].replace(',', '.', inplace = True, regex = True)
c29_2['u'].replace(',', '.',inplace = True, regex = True)
c29_2['t'] = pd.to_numeric(c29_2['t'])
c29_2['u'] = pd.to_numeric(c29_2['u'])

c29_2_u = np.array(c29_2['u'])

for i in range(400, len(c29_2['u']) - 400):
    c29_2_u[i] = np.average(c29_2['u'][i-400:i+400])

# %%
plt.plot(c29_2['t'], c29_2_u, label = 'Ток 29 А, через 5 минут')
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c29_2_u[400:49594]))
# Out:
# 0.9819999464899174

# %%
c29_3 = pd.read_csv('29_3.csv', sep = '\t')
c29_3.columns = new_columns

c29_3['t'].replace(',', '.', inplace = True, regex = True)
c29_3['u'].replace(',', '.',inplace = True, regex = True)
c29_3['t'] = pd.to_numeric(c29_3['t'])
c29_3['u'] = pd.to_numeric(c29_3['u'])

c29_3_u = np.array(c29_3['u'])

for i in range(400, len(c29_3['u']) - 400):
    c29_3_u[i] = np.average(c29_3['u'][i-400:i+400])

# %%
plt.plot(c29_3['t'], c29_3_u, label = 'Ток 29 А, через 10 минут')
plt.xlabel('t, c')
plt.ylabel('u, V')
print(np.average(c29_3_u[400:49594]))
# Out:
# 0.9851920927425092

# %%
U = np.array([np.average(c14_u[400:49594]), np.average(c16_u[400:49594]), np.average(c17_u[400:49594]), np.average(c19_u[400:49594]), np.average(c20_u[400:49594]), np.average(c22_u[400:49594]), np.average(c23_u[400:49594]), np.average(c25_u[400:49594]), np.average(c26_u[400:49594]), np.average(c28_u[400:49594]), np.average(c29_u[400:49594])])
T = np.array([1631, 1776, 1841, 1964, 2022, 2133, 2186, 2290, 2341, 2437, 2484])
T_inv = 1/T

# %%
x = np.linspace(0.0004, 0.00062, 100)

a, b, s, e = chi_sq(T_inv, U, None)
y = x * a + b

plt.plot(x, y, lw = 1, label = 'Линейная аппроксимация')
plt.scatter(T_inv, U, label = 'Экспериментальная зависимость')

plt.legend()
plt.xlabel('1/T, 1/K')
plt.ylabel('U, V')
# Out:
# Text(0, 0.5, 'U, V')

# %%
a, b, s, e
# Out:
# (-3848.1568179486285,
#  2.4652600819530854,
#  97.97007632951367,
#  0.04785437505050863)

# %%
1 - abs(s/a) #r^2
# Out:
# 0.9745410384856042

# %%
C2 = 1.438 * 10**(-2)
lambd = -0.375 * C2 /(a * np.log(10))
sig_lmbd = lambd * np.sqrt((0.001/1.438)**2 + (s/a)**2)

# %%
lambd , sig_lmbd #meters
# Out:
# (6.08585643583964e-07, 1.5499737472517388e-08)

# %%
x = np.linspace(0.12, 1, 100)

a_, b_, s_, e_ = chi_sq(U, T, None)
y = x * a_ + b_

plt.plot(x, y, lw = 1, label = 'Линейная аппроксимация')
plt.scatter(U, T, label = 'Экспериментальная зависимость')

plt.legend()
plt.xlabel('U, V')
plt.ylabel('T, K')
# Out:
# Text(0, 0.5, 'T, K')

# %%
a_, b_, s_, e_
# Out:
# (1069.0213522060506, 1456.8990383562066, 24.235287730089727, 15.78449431729204)

# %%
1 - s_/a_ #r^2
# Out:
# 0.977329463363779

# %%
0.12847911511312354 * a_ + b_
# Out:
# 1594.2459557246748

# %%
gr1 = pd.read_csv('green.csv', sep = '\t')
new_columns = list(['t', 'u'])
gr1.columns = new_columns

gr1['t'].replace(',', '.', inplace = True, regex = True)
gr1['u'].replace(',', '.',inplace = True, regex = True)
gr1['t'] = pd.to_numeric(gr1['t'])
gr1['u'] = pd.to_numeric(gr1['u'])

gr1_u = np.array(gr1['u'])

for i in range(25, len(gr1['u']) - 25):
    gr1_u[i] = np.average(gr1['u'][i-25:i+25])

# %%
plt.plot(gr1['t'], gr1['u'], label = 'Зеленая глина 1, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(gr1['t'], gr1_u, label = 'Зеленая глина 1, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_gr1 = gr1_u * a_ + b_

plt.plot(gr1['t'], T_gr1, label = 'Зеленая глина 1, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()
plt.axis([0,10,500,2500])
# Out:
# (0.0, 10.0, 500.0, 2500.0)

# %%
T_gr1 = gr1_u * a_ + b_

x1 = np.linspace(5.8, 6.3, 50)
a1, b1, s1, e1 = chi_sq(gr1['t'][29748:30498], T_gr1[29748:30498], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(5.8, 6, 50)
a2, b2, s2, e2 = chi_sq(gr1['t'][29400:29500], T_gr1[29400:29500], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(gr1['t'][28748:32498], T_gr1[28748:32498], label = 'Зеленая глина 1, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
t_gr1 = []
x = (b2 - b1)/(a1 - a2)
t_gr1.append((x * a1 + b1)) #T, K

# %%
gr2 = pd.read_csv('green2.csv', sep = '\t')
new_columns = list(['t', 'u'])
gr2.columns = new_columns

gr2['t'].replace(',', '.', inplace = True, regex = True)
gr2['u'].replace(',', '.',inplace = True, regex = True)
gr2['t'] = pd.to_numeric(gr2['t'])
gr2['u'] = pd.to_numeric(gr2['u'])

gr2_u = np.array(gr2['u'])

for i in range(25, len(gr2['u']) - 25):
    gr2_u[i] = np.average(gr2['u'][i-25:i+25])

# %%
plt.plot(gr2['t'], gr2['u'], label = 'Зеленая глина 2, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(gr2['t'], gr2_u, label = 'Зеленая глина 2, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_gr2 = gr2_u * a_ + b_

plt.plot(gr2['t'], T_gr2, label = 'Зеленая глина 2, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(3.9, 4.1, 50)
a1, b1, s1, e1 = chi_sq(gr2['t'][20000:21000], T_gr2[20000:21000], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(3.86, 3.93, 50)
a2, b2, s2, e2 = chi_sq(gr2['t'][19420:19450], T_gr2[19420:19450], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(gr2['t'][19000:22300], T_gr2[19000:22300], label = 'Зеленая глина 2, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x = (b2 - b1)/(a1 - a2)
t_gr1.append((x * a1 + b1))

# %%
print(t_gr1)
t_gr1 = np.array(t_gr1)
t_gr1_final = np.average(t_gr1)
print(t_gr1_final)

sig_g1 = 0.5 * np.sqrt((t_gr1[0] - t_gr1_final)**2 + (t_gr1_final - t_gr1[1])**2)
print(sig_g1)
# Out:
# [2069.8052600074625, 2033.0128819095644]
# 2051.4090709585134
# 13.008070024501581

# %%
w1 = pd.read_csv('white.csv', sep = '\t')
new_columns = list(['t', 'u'])
w1.columns = new_columns

w1['t'].replace(',', '.', inplace = True, regex = True)
w1['u'].replace(',', '.',inplace = True, regex = True)
w1['t'] = pd.to_numeric(w1['t'])
w1['u'] = pd.to_numeric(w1['u'])

w1_u = np.array(w1['u'])

for i in range(25, len(w1['u']) - 25):
    w1_u[i] = np.average(w1['u'][i-25:i+25])

# %%
plt.plot(w1['t'], w1['u'], label = 'Белая глина 1, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(w1['t'], w1_u, label = 'Белая глина 1, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_w1 = w1_u * a_ + b_

plt.plot(w1['t'], T_w1, label = 'Белая глина 1, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(6.4, 6.6, 50)
a1, b1, s1, e1 = chi_sq(w1['t'][32500:33000], T_w1[32500:33000], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(6.35, 6.45, 50)
a2, b2, s2, e2 = chi_sq(w1['t'][31950:32050], T_w1[31950:32050], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(w1['t'][31000:35000], T_w1[31000:35000], label = 'WHite глина , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
t_w1 = []
x = (b2 - b1)/(a1 - a2)
t_w1.append((x * a1 + b1))

# %%
w2 = pd.read_csv('white2.csv', sep = '\t')
new_columns = list(['t', 'u'])
w2.columns = new_columns

w2['t'].replace(',', '.', inplace = True, regex = True)
w2['u'].replace(',', '.',inplace = True, regex = True)
w2['t'] = pd.to_numeric(w2['t'])
w2['u'] = pd.to_numeric(w2['u'])

w2_u = np.array(w2['u'])

for i in range(25, len(w2['u']) - 25):
    w2_u[i] = np.average(w2['u'][i-25:i+25])

# %%
plt.plot(w2['t'], w2['u'], label = 'Белая глина 2, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(w2['t'], w2_u, label = 'Белая глина 2, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_w2 = w2_u * a_ + b_

plt.plot(w2['t'], T_w2, label = 'Белая глина 2, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(6.7, 7, 50)
a1, b1, s1, e1 = chi_sq(w2['t'][34000:35000], T_w2[34000:35000], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(6.67, 6.76, 50)
a2, b2, s2, e2 = chi_sq(w2['t'][33450:33550], T_w2[33450:33550], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(w2['t'][33000:36000], T_w2[33000:36000], label = 'WHite глина , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x = (b2 - b1)/(a1 - a2)
t_w1.append((x * a1 + b1))

# %%
print(t_w1)
t_w1 = np.array(t_w1)
t_w1_final = np.average(t_w1)
print(t_w1_final)

sig_w1 = 0.5 * np.sqrt((t_w1[0] - t_w1_final)**2 + (t_w1_final - t_w1[1])**2)
print(sig_w1)
# Out:
# [2020.1711459076105, 2047.2736380573133]
# 2033.7223919824619
# 9.582177993055014

# %%
al1 = pd.read_csv('al203.csv', sep = '\t')
new_columns = list(['t', 'u'])
al1.columns = new_columns

al1['t'].replace(',', '.', inplace = True, regex = True)
al1['u'].replace(',', '.',inplace = True, regex = True)
al1['t'] = pd.to_numeric(al1['t'])
al1['u'] = pd.to_numeric(al1['u'])

al1_u = np.array(al1['u'])

for i in range(25, len(al1['u']) - 25):
    al1_u[i] = np.average(al1['u'][i-25:i+25])

# %%
plt.plot(al1['t'], al1['u'], label = 'Al$_{2}$O$_{3}$, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(al1['t'], al1_u, label = 'Al$_{2}$O$_{3}$, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_al1 = al1_u * a_ + b_

plt.plot(al1['t'], T_al1, label = 'Al$_{2}$O$_{3}$, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
#x1 = np.linspace(6.7, 7, 50)
#a1, b1, s1, e1 = chi_sq(w2['t'][34000:35000], T_w2[34000:35000], None)
#y1 = a1 * x1 + b1
#plt.plot(x1, y1)

x2 = np.linspace(6.2, 6.4, 50)
a2, b2, s2, e2 = chi_sq(al1['t'][31896:32000], T_al1[31896:32000], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(al1['t'][30000:33000], T_al1[30000:33000], label = 'al203 , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
a2, b2, s2, e2
# Out:
# (-8.57422973734144, 2306.377621395071, 15.179561113546665, 96.99288334487736)

# %%
t_al = []
t_al.append(b2)

# %%
al2 = pd.read_csv('al203_2.csv', sep = '\t')
new_columns = list(['t', 'u'])
al2.columns = new_columns

al2['t'].replace(',', '.', inplace = True, regex = True)
al2['u'].replace(',', '.',inplace = True, regex = True)
al2['t'] = pd.to_numeric(al2['t'])
al2['u'] = pd.to_numeric(al2['u'])

al2_u = np.array(al2['u'])

for i in range(25, len(al2['u']) - 25):
    al2_u[i] = np.average(al2['u'][i-25:i+25])

# %%
plt.plot(al2['t'], al2['u'], label = 'Al$_{2}$O$_{3}$  2, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(al2['t'], al2_u, label = 'Al$_{2}$O$_{3}$  2, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_al2 = al2_u * a_ + b_

plt.plot(al2['t'], T_al2, label = 'Al$_{2}$O$_{3}$  2, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
#x1 = np.linspace(6.7, 7, 50)
#a1, b1, s1, e1 = chi_sq(w2['t'][34000:35000], T_w2[34000:35000], None)
#y1 = a1 * x1 + b1
#plt.plot(x1, y1)

x2 = np.linspace(7.1, 7.3, 50)
a2, b2, s2, e2 = chi_sq(al2['t'][36180:36400], T_al2[36180:36400], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(al2['t'][35000:37500], T_al2[35000:37500], label = 'al203 , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
a2, b2, s2, e2
# Out:
# (0.11846220580273581, 2248.9437168540144, 7.650797180132101, 55.53034697335393)

# %%
t_al.append(b2)

print(t_al)
t_al = np.array(t_al)
t_al_final = np.average(t_al)
print(t_al_final)

sig_al = 0.5 * np.sqrt((t_al[0] - t_al_final)**2 + (t_al_final - t_al[1])**2)
print(sig_al)
# Out:
# [2306.377621395071, 2248.9437168540144]
# 2277.6606691245424
# 20.305951685500972

# %%
zr1 = pd.read_csv('ZrO2.csv', sep = '\t')
new_columns = list(['t', 'u'])
zr1.columns = new_columns

zr1['t'].replace(',', '.', inplace = True, regex = True)
zr1['u'].replace(',', '.',inplace = True, regex = True)
zr1['t'] = pd.to_numeric(zr1['t'])
zr1['u'] = pd.to_numeric(zr1['u'])

zr1_u = np.array(zr1['u'])

for i in range(25, len(zr1['u']) - 25):
    zr1_u[i] = np.average(zr1['u'][i-25:i+25])

# %%
plt.plot(zr1['t'], zr1['u'], label = 'ZrO$_{2}$, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(zr1['t'], zr1_u, label = 'ZrO$_{2}$, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_zr1 = zr1_u * a_ + b_

plt.plot(zr1['t'], T_zr1, label = 'ZrO$_{2}$, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(6.3, 6.5, 50)
a1, b1, s1, e1 = chi_sq(zr1['t'][31700:31900], T_zr1[31700:31900], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(6.3, 6.6, 50)
a2, b2, s2, e2 = chi_sq(zr1['t'][32200:32500], T_zr1[32200:32500], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(zr1['t'][31000:35000], T_zr1[31000:35000], label = 'zro2 , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
t_zr = []
x = (b2 - b1)/(a1 - a2)
t_zr.append((x * a1 + b1))

# %%
zr2 = pd.read_csv('ZrO2_2.csv', sep = '\t')
new_columns = list(['t', 'u'])
zr2.columns = new_columns

zr2['t'].replace(',', '.', inplace = True, regex = True)
zr2['u'].replace(',', '.',inplace = True, regex = True)
zr2['t'] = pd.to_numeric(zr2['t'])
zr2['u'] = pd.to_numeric(zr2['u'])

zr2_u = np.array(zr2['u'])

for i in range(25, len(zr2['u']) - 25):
    zr2_u[i] = np.average(zr2['u'][i-25:i+25])

# %%
plt.plot(zr2['t'], zr2['u'], label = 'ZrO$_{2}$  2, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(zr2['t'], zr2_u, label = 'ZrO$_{2}$  2, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_zr2 = zr2_u * a_ + b_

plt.plot(zr2['t'], T_zr2, label = 'ZrO$_{2}$  2, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(6.3, 6.5, 50)
a1, b1, s1, e1 = chi_sq(zr2['t'][31695:31700], T_zr2[31695:31700], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(6.3, 6.6, 50)
a2, b2, s2, e2 = chi_sq(zr2['t'][32400:32600], T_zr2[32400:32600], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(zr2['t'][31000:35000], T_zr2[31000:35000], label = 'zro2 , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x = (b2 - b1)/(a1 - a2)
t_zr.append((x * a1 + b1))

print(t_zr)
t_zr = np.array(t_zr)
t_zr_final = np.average(t_zr)
print(t_zr_final)

sig_zr = 0.5 * np.sqrt((t_zr[0] - t_zr_final)**2 + (t_zr_final - t_zr[1])**2)
print(sig_zr)
# Out:
# [2250.5394786563265, 2439.1772279988]
# 2344.8583533275632
# 66.69351587391557

# %%
ti1 = pd.read_csv('TiO2.csv', sep = '\t')
new_columns = list(['t', 'u'])
ti1.columns = new_columns

ti1['t'].replace(',', '.', inplace = True, regex = True)
ti1['u'].replace(',', '.',inplace = True, regex = True)
ti1['t'] = pd.to_numeric(ti1['t'])
ti1['u'] = pd.to_numeric(ti1['u'])

ti1_u = np.array(ti1['u'])

for i in range(25, len(ti1['u']) - 25):
    ti1_u[i] = np.average(ti1['u'][i-25:i+25])

# %%
plt.plot(ti1['t'], ti1['u'], label = 'TiO$_{2}$, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(ti1['t'], ti1_u, label = 'TiO$_{2}$, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_ti1 = ti1_u * a_ + b_

plt.plot(ti1['t'], T_ti1, label = 'TiO$_{2}$, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(6.53, 6.6, 50)
a1, b1, s1, e1 = chi_sq(ti1['t'][32755:32800], T_ti1[32755:32800], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(6.55, 6.65, 50)
a2, b2, s2, e2 = chi_sq(ti1['t'][33600:34000], T_ti1[33600:34000], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(ti1['t'][32000:35000], T_ti1[32000:35000], label = 'tio2 , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
t_ti = []
x = (b2 - b1)/(a1 - a2)
t_ti.append((x * a1 + b1))

# %%
ti2 = pd.read_csv('TiO2_2.csv', sep = '\t')
new_columns = list(['t', 'u'])
ti2.columns = new_columns

ti2['t'].replace(',', '.', inplace = True, regex = True)
ti2['u'].replace(',', '.',inplace = True, regex = True)
ti2['t'] = pd.to_numeric(ti2['t'])
ti2['u'] = pd.to_numeric(ti2['u'])

ti2_u = np.array(ti2['u'])

for i in range(25, len(ti2['u']) - 25):
    ti2_u[i] = np.average(ti2['u'][i-25:i+25])

# %%
plt.plot(ti2['t'], ti2['u'], label = 'TiO$_{2}$ 2, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(ti2['t'], ti2_u, label = 'TiO$_{2}$ 2, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_ti2 = ti2_u * a_ + b_

plt.plot(ti2['t'], T_ti2, label = 'TiO$_{2}$ 2, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(6.4, 6.45, 50)
a1, b1, s1, e1 = chi_sq(ti2['t'][32100:32150], T_ti2[32100:32150], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(6.4, 6.5, 50)
a2, b2, s2, e2 = chi_sq(ti2['t'][33750:34000], T_ti2[33750:34000], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(ti2['t'][32000:35000], T_ti2[32000:35000], label = 'tio2 , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x = (b2 - b1)/(a1 - a2)
t_ti.append((x * a1 + b1))

# %%
ti3 = pd.read_csv('TiO2_3.csv', sep = '\t')
new_columns = list(['t', 'u'])
ti3.columns = new_columns

ti3['t'].replace(',', '.', inplace = True, regex = True)
ti3['u'].replace(',', '.',inplace = True, regex = True)
ti3['t'] = pd.to_numeric(ti3['t'])
ti3['u'] = pd.to_numeric(ti3['u'])

ti3_u = np.array(ti3['u'])

for i in range(25, len(ti3['u']) - 25):
    ti3_u[i] = np.average(ti3['u'][i-25:i+25])

# %%
plt.plot(ti3['t'], ti3['u'], label = 'TiO$_{2}$ 3, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(ti3['t'], ti3_u, label = 'TiO$_{2}$ 3, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_ti3 = ti3_u * a_ + b_

plt.plot(ti3['t'], T_ti3, label = 'TiO$_{2}$ 3, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(7.35, 7.4, 50)
a1, b1, s1, e1 = chi_sq(ti3['t'][36900:36960], T_ti3[36900:36960], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(7.3, 7.5, 50)
a2, b2, s2, e2 = chi_sq(ti3['t'][37100:37200], T_ti3[37100:37200], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(ti3['t'][36000:40000], T_ti3[36000:40000], label = 'tio2 , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x = (b2 - b1)/(a1 - a2)
t_ti.append((x * a1 + b1))

# %%
ti4 = pd.read_csv('TiO2_hmmm.csv', sep = '\t')
new_columns = list(['t', 'u'])
ti4.columns = new_columns

ti4['t'].replace(',', '.', inplace = True, regex = True)
ti4['u'].replace(',', '.',inplace = True, regex = True)
ti4['t'] = pd.to_numeric(ti4['t'])
ti4['u'] = pd.to_numeric(ti4['u'])

ti4_u = np.array(ti4['u'])

for i in range(25, len(ti4['u']) - 25):
    ti4_u[i] = np.average(ti4['u'][i-25:i+25])

# %%
plt.plot(ti4['t'], ti4['u'], label = 'TiO$_{2}$ 4, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(ti4['t'], ti4_u, label = 'TiO$_{2}$ 4, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_ti4 = ti4_u * a_ + b_

plt.plot(ti4['t'], T_ti4, label = 'TiO$_{2}$ 4, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(7.25, 7.3, 50)
a1, b1, s1, e1 = chi_sq(ti4['t'][36270:36360], T_ti4[36270:36360], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(7.25, 7.4, 50)
a2, b2, s2, e2 = chi_sq(ti4['t'][37300:37350], T_ti4[37300:37350], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(ti4['t'][36000:40000], T_ti4[36000:40000], label = 'tio2 , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x = (b2 - b1)/(a1 - a2)
t_ti.append((x * a1 + b1))

# %%
ti5 = pd.read_csv('TiO2_hmmm_2.csv', sep = '\t')
new_columns = list(['t', 'u'])
ti5.columns = new_columns

ti5['t'].replace(',', '.', inplace = True, regex = True)
ti5['u'].replace(',', '.',inplace = True, regex = True)
ti5['t'] = pd.to_numeric(ti5['t'])
ti5['u'] = pd.to_numeric(ti5['u'])

ti5_u = np.array(ti5['u'])

for i in range(25, len(ti5['u']) - 25):
    ti5_u[i] = np.average(ti5['u'][i-25:i+25])

# %%
plt.plot(ti5['t'], ti5['u'], label = 'TiO$_{2}$ 5, без усреднения')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
plt.plot(ti5['t'], ti5_u, label = 'TiO$_{2}$ 5, с усреднением')

plt.xlabel('t,c')
plt.ylabel('U,V')
plt.legend()

# %%
T_ti5 = ti5_u * a_ + b_

plt.plot(ti5['t'], T_ti5, label = 'TiO$_{2}$ 5, температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x1 = np.linspace(8.38, 8.42, 50)
a1, b1, s1, e1 = chi_sq(ti5['t'][41950:42000], T_ti5[41950:42000], None)
y1 = a1 * x1 + b1
plt.plot(x1, y1)

x2 = np.linspace(8.35, 8.5, 50)
a2, b2, s2, e2 = chi_sq(ti5['t'][42100:42300], T_ti5[42100:42300], None)
y2 = a2 * x2 + b2
plt.plot(x2, y2)

plt.plot(ti5['t'][41000:45000], T_ti5[41000:45000], label = 'tio2 , температурная зависимость')

plt.xlabel('t, c')
plt.ylabel('T, K')
plt.legend()

# %%
x = (b2 - b1)/(a1 - a2)
t_ti.append((x * a1 + b1))

print(t_ti)
t_ti = np.array(t_ti)
t_ti_final = np.average(t_ti)
print(t_ti_final)

sig_ti = 1/5 * np.sqrt((t_ti[0] - t_ti_final)**2 + (t_ti_final - t_ti[1])**2 + (t_ti_final - t_ti[2])**2 + (t_ti_final - t_ti[3])**2 + (t_ti_final - t_ti[4])**2)
print(sig_ti)
# Out:
# [2067.0203422071936, 2074.0300789880275, 2129.3436882895767, 2132.993161141858, 2118.098225635302]
# 2104.2970992523915
# 12.56489683409923

# %%
sig_ti = 1/5 * np.sqrt((t_ti[0] - t_ti_final)**2 + (t_ti_final - t_ti[1])**2 + (t_ti_final - t_ti[2])**2 + (t_ti_final - t_ti[3])**2 + (t_ti_final - t_ti[4])**2)
print(sig_ti)
# Out:
# 12.56489683409923

# %%
melt = np.array([t_gr1_final, t_w1_final, t_al_final, t_zr_final, t_ti_final])
sigm = np.array([sig_g1, sig_w1, sig_al, sig_zr, sig_ti])
names = np.array(['Green', 'White', 'Al$_{2}$O$_{3}$', 'ZrO$_{2}$', 'TiO$_{2}$'])

# %%
df = pd.DataFrame(np.array([names, melt, sigm]))
df.insert(0, 'Name', ['Material', 'T$_{я}$, K', '$\sigma$, K'])

df.style.set_caption('Таблица 1').hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_ee3d91fa_b66f_11ec_89af_7cb27d0424ea" ><caption>Таблица 1</caption><thead>    <tr>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >0</th>        <th class="col_heading level0 col2" >1</th>        <th class="col_heading level0 col3" >2</th>        <th class="col_heading level0 col4" >3</th>        <th class="col_heading level0 col5" >4</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ee3d91fa_b66f_11ec_89af_7cb27d0424earow0_col0" class="data row0 col0" >Material</td>
#                         <td id="T_ee3d91fa_b66f_11ec_89af_7cb27d0424earow0_col1" class="data row0 col1" >Green</td>
#                         <td id="T_ee3d91fa_b66f_11ec_89af_7cb27d0424earow0_col2" class="data row0 col2" >White</td>
#                         <td id="T_ee3d91fa_b66f_11ec_89af_7cb27d0424earow0_col3" class="data row0 col3" >Al$_{2}$O$_{3}$</td>
# ...

# %%
lambd , sig_lmbd #meters
# Out:
# (6.08585643583964e-07, 1.5499737472517388e-08)

# %%
eps = [0.91, 0.91, 0.4, 0.9, 0.8]

# %%
T_true = np.zeros(len(melt))
for i in range(len(melt)):
    T_true[i] = 1/(1/melt[i] - lambd/C2 * np.log10(1/eps[i]))

# %%
sig_T_true = np.zeros(len(melt))
for i in range(len(melt)):
    sig_T_true[i] = T_true[i] * np.sqrt((sigm[i]/melt[i])**2 + (sig_lmbd/lambd)**2 + (0.001/1.438)**2)

# %%
T_true, sig_T_true
# Out:
# (array([2058.72988952, 2040.91729723, 2368.51498911, 2355.55468399,
#         2122.61644887]),
#  array([54.05233333, 52.88006521, 63.9327038 , 89.94699857, 55.54524846]))

# %%
df = pd.DataFrame(np.array([names, T_true, sig_T_true]))
df.insert(0, 'Name', ['Material', 'T$_{и}$, K', '$\sigma$, K'])

df.style.set_caption('Таблица 2').hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_d3604873_b67a_11ec_b49f_7cb27d0424ea" ><caption>Таблица 2</caption><thead>    <tr>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >0</th>        <th class="col_heading level0 col2" >1</th>        <th class="col_heading level0 col3" >2</th>        <th class="col_heading level0 col4" >3</th>        <th class="col_heading level0 col5" >4</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d3604873_b67a_11ec_b49f_7cb27d0424earow0_col0" class="data row0 col0" >Material</td>
#                         <td id="T_d3604873_b67a_11ec_b49f_7cb27d0424earow0_col1" class="data row0 col1" >Green</td>
#                         <td id="T_d3604873_b67a_11ec_b49f_7cb27d0424earow0_col2" class="data row0 col2" >White</td>
#                         <td id="T_d3604873_b67a_11ec_b49f_7cb27d0424earow0_col3" class="data row0 col3" >Al$_{2}$O$_{3}$</td>
# ...

# %%
C1 = 3.4713 * 10**(-16)
sig_C1 = 0.0002 * 10**(-16)

# %%
E_1 = C1 * (650 * 10**(-9))**(-5) * 1/(np.exp(C2/(650 * 10**(-9) * 1000)) - 1) * 10*10**(-9)
E_2 = C1 * (650 * 10**(-9))**(-5) * 1/(np.exp(C2/(650 * 10**(-9) * 2000)) - 1)* 10*10**(-9)

# %%
E_1, E_2
# Out:
# (0.0073789596375001265, 469.85848116978974)

# %%
eps_2 = 0.43

# %%
T_color = np.zeros(len(melt))

for i in range(len(melt)):
    T_color[i] = 1/(1/T_true[i] - np.log10(eps[i]/eps_2)/(C2 * (1/lambd - 1/(650 * 10**(-9)))))

# %%
T_color
# Out:
# array([3710.88226813, 3653.40744587, 2256.98864395, 4729.08519135,
#        3424.38579392])

# %%
koef = np.zeros(len(melt)) 
for i in range(len(melt)):
    koef[i] = np.exp(C2/(lambd * T_true[i]))/(np.exp(C2/(lambd * T_true[i]) - 1))

# %%
koef
# Out:
# array([2.71828183, 2.71828183, 2.71828183, 2.71828183, 2.71828183])

# %%
sig_sum = T_true * np.sqrt((koef/T_true)**2 + (sig_T_true/T_true)**2)

# %%
sig_sum
# Out:
# array([54.12064112, 52.9498853 , 63.99046548, 89.98806369, 55.61172253])

# %%
t_al
# Out:
# array([2306.3776214 , 2248.94371685])

# %%
t_ti
# Out:
# array([2067.02034221, 2074.03007899, 2129.34368829, 2132.99316114,
#        2118.09822564])
